# %%
import pandas as pd
from matplotlib import pyplot as plt

data= pd.read_csv("D:/food_delivery_datasets.csv")

# %%
print(data)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
data.head()
# Out:
#      order_id  voucher_amount                   date_time  eta_seconds  \
# 0  FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1  FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2  FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3  FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4  FOOD-10961               0  2018-09-22T17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587

# %%
data.max()
# Out:
# order_id                          FOOD-11076
# voucher_amount                         25000
# date_time         2018-09-30T20:17:40.796955
# eta_seconds                             6082
# food_price                            448500
# cust_id                              1548571
# rating                                     5
# delivery_fee                           44000
# resto_id                           742814735
# status                             Completed
# random_id                           0.999124
# dtype: object

# %%
data.min()
# Out:
# order_id                          FOOD-10001
# voucher_amount                             0
# date_time         2018-07-01T11:36:10.581264
# eta_seconds                                2
# food_price                             12900
# cust_id                                22895
# rating                                     1
# delivery_fee                               0
# resto_id                           200000639
# status                             Cancelled
# random_id                          0.0016161
# dtype: object

# %%
data.nsmallest(3,'delivery_fee')
# Out:
#       order_id  voucher_amount                   date_time  eta_seconds  \
# 8   FOOD-10342           10000  2018-08-03T13:58:54.286742         1265
# 16  FOOD-10978            4000  2018-09-23T14:18:37.731404         1204
# 31  FOOD-10410           10000  2018-08-09T20:06:09.394736         1074
#
#     food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 8        37500   304856     5.0             0  742670531  Completed   0.373261
# 16       33100  1163202     5.0             0  742531705  Completed   0.596303
# 31       32800   588886     5.0             0  742715861  Completed   0.455108

# %%
data.nlargest(3,'delivery_fee')
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 1032  FOOD-10382               0  2018-08-05T22:18:54.638622         2887
# 374   FOOD-10845               0  2018-09-16T11:52:48.597895           45
# 731   FOOD-10381               0  2018-08-05T22:15:05.095392          215
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# 1032      141400  1383625     NaN         44000  200003382  Completed
# 374       241100  1294885     NaN         43000  742526665  Cancelled
# 731       142100  1383625     NaN         43000  200003382  Cancelled
#
#       random_id
# 1032   0.138681
# 374    0.304505
# 731    0.894978

# %%
x=data['resto_id'].unique()

# %%
print(len(x))
# Out:
# 671

# %%
data['resto_id'].unique()
# Out:
# array([742638033, 742767245, 742618303, 742541172, 742604875, 225641128,
#        742550960, 742534099, 742670531, 742554110, 742594125, 742544599,
#        742538990, 742630797, 742531018, 742531705, 742531121, 742618679,
#        742676756, 742756630, 742531805, 742656058, 742702327, 200005639,
#        742759541, 742676336, 742616723, 742731698, 742539196, 742715861,
#        742669465, 742721020, 742537745, 742766593, 742538372, 742530083,
#        742645112, 742675089, 742604626, 200002164, 742560026, 742596825,
#        742687000, 742663872, 742549966, 742765974, 742620545, 742650491,
#        742641772, 742605418, 742753560, 742542838, 742604525, 742691600,
#        742534610, 742784023, 742781399, 742639682, 742759889, 742669355,
#        742792299, 742622470, 742526724, 742735098, 742606500, 742525710,
#        742643190, 742652462, 742554079, 742591683, 742641833, 200009033,
#        742784386, 742536407, 742540911, 742586988, 742602057, 742598967,
# ...

# %%
data['resto_id'].count()
# Out:
# 1076

# %%
data_groupby_resto= data.groupby('resto_id')

# %%
data_groupby_resto['resto_id'].count()
# Out:
# resto_id
# 200000639    1
# 200000964    2
# 200001006    1
# 200001973    1
# 200001979    1
#             ..
# 742808523    1
# 742809792    1
# 742810086    1
# 742813095    2
# 742814735    1
# Name: resto_id, Length: 671, dtype: int64
